# %%
# %matplotlib notebook
# %reload_ext autoreload
# %autoreload 2
import warnings; warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import matplotlib as mpl
from gibs.wp import timeseriesplots

mpl.rcParams.update({
    "pgf.texsystem": "xelatex",
    #'font.family': 'sans-serif',
    #'text.usetex': True,
    'pgf.rcfonts': False,
    'figure.dpi': 120, # Change this to scale all figures
    'figure.titlesize': 14,
    'axes.unicode_minus': False,
})

plt.rcParams["font.family"] = "serif"
plt.rcParams["mathtext.fontset"] = "dejavuserif"

# %%
def read_tidy(f):
    df = pd.read_csv(f, sep=',')
    timestamp = pd.to_datetime(df.pop('timestamp'), utc=True)
    df.index = timestamp
    return df

# %%
path = "/home/migusb/projects/hackathons/La-Conga2022/img_average.csv"

# %%
df = read_tidy(path)

# %%
df.index
# Out:
# DatetimeIndex(['2003-03-09 12:00:00+00:00', '2003-04-01 00:00:00+00:00',
#                '2003-04-01 03:00:00+00:00', '2003-04-01 12:00:00+00:00',
#                '2003-04-02 00:00:00+00:00', '2003-04-02 03:00:00+00:00',
#                '2003-04-02 12:00:00+00:00', '2003-04-03 00:00:00+00:00',
#                '2003-04-03 03:00:00+00:00', '2003-04-03 12:00:00+00:00',
#                ...
#                '2012-08-08 06:00:00+00:00', '2012-08-09 06:00:00+00:00',
#                '2012-09-01 06:00:00+00:00', '2012-09-03 06:00:00+00:00',
#                '2012-09-04 06:00:00+00:00', '2012-09-05 06:00:00+00:00',
#                '2012-09-06 06:00:00+00:00', '2012-09-07 06:00:00+00:00',
#                '2012-09-08 06:00:00+00:00', '2012-09-09 06:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', name='timestamp', length=2856, freq=None)

# %%
vdf = df.copy()

# %%
(vdf>-1).replace(True, np.nan)
# Out:
#                            average
# timestamp
# 2003-03-09 12:00:00+00:00      NaN
# 2003-04-01 00:00:00+00:00      NaN
# 2003-04-01 03:00:00+00:00      NaN
# 2003-04-01 12:00:00+00:00      NaN
# 2003-04-02 00:00:00+00:00      NaN
# ...                            ...
# 2012-09-05 06:00:00+00:00      NaN
# 2012-09-06 06:00:00+00:00      NaN
# 2012-09-07 06:00:00+00:00      NaN
# 2012-09-08 06:00:00+00:00      NaN
# 2012-09-09 06:00:00+00:00      NaN
#
# [2856 rows x 1 columns]

# %%
fig, ax = timeseriesplots({'None':(vdf>-1).replace(True, np.nan), 'Daily data':df}, ylabel= 'satellite image average')
# Out:
# <img src="data:image/png;base64,..." width="1920">
